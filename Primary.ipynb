# %%
import os
import time
import shutil
import tempfile
import matplotlib
import matplotlib.pyplot as plt
from pathlib import Path
import numpy as np
import psutil
import tensorflow as tf
from tensorflow.keras.applications import MobileNetV3Small
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, accuracy_score


# ⏲️ Monitor system usage
def print_system_usage(phase):
    memory = psutil.virtual_memory()
    cpu = psutil.cpu_percent(interval=1)
    print(f"[{phase}] CPU Usage: {cpu:.2f}% | RAM Usage: {memory.percent:.2f}% ({memory.used / 1e9:.2f} GB used)")


# 🛠️ Create temporary folder with only 'Healthy' and 'Unhealthy' classes
def create_binary_temp_dataset(original_path):
    temp_dir = tempfile.mkdtemp()
    healthy_dir = Path(temp_dir) / "Healthy"
    unhealthy_dir = Path(temp_dir) / "Unhealthy"
    healthy_dir.mkdir(parents=True, exist_ok=True)
    unhealthy_dir.mkdir(parents=True, exist_ok=True)

    for class_dir in Path(original_path).iterdir():
        if not class_dir.is_dir():
            continue
        target_dir = healthy_dir if class_dir.name.lower() == "healthy" else unhealthy_dir
        for img_file in class_dir.glob("*.*"):
            shutil.copy(img_file, target_dir / img_file.name)
    return temp_dir


# 🧪 Load and preprocess binary-class image data
def load_data_from_folder(path, target_size=(96, 96), batch_size=16):
    binary_path = create_binary_temp_dataset(path)
    datagen = ImageDataGenerator(preprocessing_function=tf.keras.applications.mobilenet_v3.preprocess_input)
    return datagen.flow_from_directory(
        binary_path,
        target_size=target_size,
        batch_size=batch_size,
        class_mode='binary',
        shuffle=False
    )


# 🧠 Build lightweight MobileNetV3 model
def build_model():
    base = MobileNetV3Small(weights='imagenet', include_top=False, input_shape=(96, 96, 3))
    base.trainable = False
    x = GlobalAveragePooling2D()(base.output)
    out = Dense(1, activation='sigmoid')(x)
    model = Model(inputs=base.input, outputs=out)
    model.compile(optimizer=Adam(0.0001), loss='binary_crossentropy', metrics=['accuracy'])
    return model


# 📁 Set dataset paths
train_path = os.path.join("Potato", "Train")
val_path = os.path.join("Potato", "Val")
test_path = os.path.join("Potato", "Test")

# 📦 Load data
print("📦 Loading data...")
train_gen = load_data_from_folder(train_path)
val_gen = load_data_from_folder(val_path)
test_gen = load_data_from_folder(test_path)
print_system_usage("After loading data")

# ✅ Inspect a sample batch
x_batch, y_batch = next(train_gen)
print("Min pixel value:", np.min(x_batch))
print("Max pixel value:", np.max(x_batch))
print(f"🔍 Sample image shape: {x_batch[0].shape}")

# 🧠 Build and train model
print("\n🚀 Training model...")
start_time = time.time()
model = build_model()
model.fit(train_gen, validation_data=val_gen, epochs=5)
training_duration = time.time() - start_time
print(f"⏱️ Training completed in {training_duration:.2f} seconds.")
print_system_usage("After training")

# 🧪 Evaluate on test data
print("\n🎯 Test Set Results:")
test_gen.reset()
y_true = test_gen.classes
y_pred_probs = model.predict(test_gen, verbose=0)
y_pred = (y_pred_probs > 0.5).astype(int).reshape(-1)

print("Accuracy:", accuracy_score(y_true, y_pred))
print_system_usage("After prediction (Test)")
print(classification_report(y_true, y_pred, target_names=["Healthy", "Unhealthy"]))

# 📊 Confusion matrix
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Healthy", "Unhealthy"])
disp.plot()

# 💾 Save model
model.save("mobilenetv3_leaf_model.h5")
print("\n💾 Model saved as 'mobilenetv3_leaf_model.h5'")

# 🛸 Convert to TFLite (for Raspberry Pi deployment)
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
with open("mobilenetv3_leaf_model.tflite", "wb") as f:
    f.write(tflite_model)
print("✨ TFLite model saved as 'mobilenetv3_leaf_model.tflite'")


# 📸 Show sample predictions
matplotlib.rcParams['font.family'] = 'Arial'

def show_predictions(generator, model, class_names=["Healthy", "Unhealthy"], num_samples=8):
    print("\n🖼️ Showing sample predictions:")
    generator.reset()
    x, y_true = next(generator)
    y_pred_probs = model.predict(x)
    y_pred = (y_pred_probs > 0.5).astype(int).reshape(-1)

    plt.figure(figsize=(15, 6))
    for i in range(min(num_samples, len(x))):
        plt.subplot(2, 4, i + 1)
        # Convert from [-1, 1] to [0, 1] and clip
        img = np.clip((x[i] + 1) / 2.0, 0, 1)
        plt.imshow(img)
        plt.axis('off')

        true_label = class_names[int(y_true[i])]
        pred_label = class_names[int(y_pred[i])]

        # Color prediction in red if wrong
        color = 'green' if true_label == pred_label else 'red'
        plt.title(f"Pred: {pred_label}\nTrue: {true_label}", color=color)

    plt.tight_layout()
    plt.show()

# 🖼️ Call the function to display
show_predictions(test_gen, model)
# Out:
# 📦 Loading data...
# Found 5702 images belonging to 2 classes.
# Found 1282 images belonging to 2 classes.
# Found 144 images belonging to 2 classes.
# [After loading data] CPU Usage: 20.10% | RAM Usage: 76.00% (12.85 GB used)
# Min pixel value: 0.0
# Max pixel value: 255.0
# 🔍 Sample image shape: (96, 96, 3)
#
# 🚀 Training model...
# D:\Deep_Learning\Hackathon\.venv\lib\site-packages\keras\src\applications\mobilenet_v3.py:452: UserWarning: `input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
#   return MobileNetV3(
# Epoch 1/5
# D:\Deep_Learning\Hackathon\.venv\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 17s 39ms/step - accuracy: 0.5375 - loss: 0.7273 - val_accuracy: 0.7005 - val_loss: 0.5660
# Epoch 2/5
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step - accuracy: 0.7155 - loss: 0.5356 - val_accuracy: 0.7902 - val_loss: 0.4462
# Epoch 3/5
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step - accuracy: 0.8121 - loss: 0.4292 - val_accuracy: 0.8713 - val_loss: 0.3675
# Epoch 4/5
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 9s 26ms/step - accuracy: 0.8683 - loss: 0.3732 - val_accuracy: 0.9181 - val_loss: 0.3136
# Epoch 5/5
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step - accuracy: 0.9166 - loss: 0.3190 - val_accuracy: 0.9337 - val_loss: 0.2753
# ⏱️ Training completed in 56.07 seconds.
# [After training] CPU Usage: 13.20% | RAM Usage: 75.80% (12.81 GB used)
#
# 🎯 Test Set Results:
# Accuracy: 0.9305555555555556
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [After prediction (Test)] CPU Usage: 11.50% | RAM Usage: 75.90% (12.83 GB used)
#               precision    recall  f1-score   support
#
#      Healthy       0.93      0.85      0.89        46
#    Unhealthy       0.93      0.97      0.95        98
#
#     accuracy                           0.93       144
#    macro avg       0.93      0.91      0.92       144
# weighted avg       0.93      0.93      0.93       144
#
#
# 💾 Model saved as 'mobilenetv3_leaf_model.h5'
# INFO:tensorflow:Assets written to: C:\Users\rajde\AppData\Local\Temp\tmp3n5n44j_\assets
# INFO:tensorflow:Assets written to: C:\Users\rajde\AppData\Local\Temp\tmp3n5n44j_\assets
# Saved artifact at 'C:\Users\rajde\AppData\Local\Temp\tmp3n5n44j_'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 96, 96, 3), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   1789514723072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789514933248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789514937120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789514931312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789514935888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789514934656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515272384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515272912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515269040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515272560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789514933952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515280128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515284176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515278896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515280304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515353600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515356240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515352192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515354128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515360992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515359936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515362576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515358528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515360464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515352544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515483792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515486256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515481680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515485200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515492064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515491008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515493648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515489600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515491536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515495232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515547568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515546864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515496288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515546688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515489952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515554080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515556720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515552672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515554608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515562528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515559008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515558304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515559712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515558656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515553024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515651152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515653792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515649744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515651680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515649392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515657664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515656960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515659072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789517644720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515650096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789517652640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789517656688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789517648768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789517658976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789517743024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789517742672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789517742848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789517744784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789515660128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789517749712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789517752000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789517747600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789517751120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789517757984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789517754464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789517753760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789517755168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789517754112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789517747776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789517865280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789517869328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789517861408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789517871616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789517972048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789517971696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789517870912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789517973808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789517981024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789517979968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789517982608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789517978560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789517980496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789517985424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518070528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518071584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789517986480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518069824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789517978912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518079504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518083552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518075632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518085840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518169888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518172000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518168128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518171648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518178864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518177808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518180448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518176400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518178336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518183264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518234544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518234192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518234368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518236304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518244576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518236832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518248624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518240704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518244752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518367904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518370544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518366496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518368432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518235776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518374240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518376880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518372832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518374768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518379696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518463744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518463392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518378992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518465504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518373184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518473776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518477824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518469904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518473952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518580896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518583360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518578784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518582304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518589520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518588464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518591104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518587056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518588992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789518578960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535243776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535246416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535242368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535244304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535253632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535242016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535249760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535255216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535253808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535360576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535363216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535359168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535361104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535367968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535366912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535369552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535365504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535367440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535359520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535440208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535442848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535438800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535440736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535450064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535438448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535446192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535451648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535450240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535557008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535559648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535555600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535557536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535565808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535564752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535567392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535563344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535565280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535555952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535638048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535640688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535636640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535638576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535647904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535636288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535644032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535649488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535648080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535754848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535757488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535753440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535755376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535763648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535760128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535759424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535760832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535763824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789512352512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1789535835536: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ✨ TFLite model saved as 'mobilenetv3_leaf_model.tflite'
#
# 🖼️ Showing sample predictions:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 722ms/step
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family ['DejaVu Sans'] not found. Falling back to DejaVu Sans.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 151
#     148     plt.show()
#     150 # 🖼️ Call the function to display
# --> 151 show_predictions(test_gen, model)
#
# Cell In[1], line 147, in show_predictions(generator, model, class_names, num_samples)
#     144     color = 'green' if true_label == pred_label else 'red'
#     145     plt.title(f"Pred: {pred_label}\nTrue: {true_label}", color=color)
# --> 147 plt.tight_layout()
#     148 plt.show()
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\pyplot.py:2833, in tight_layout(pad, h_pad, w_pad, rect)
#    2825 @_copy_docstring_and_deprecators(Figure.tight_layout)
#    2826 def tight_layout(
#    2827     *,
#    (...)
#    2831     rect: tuple[float, float, float, float] | None = None,
#    2832 ) -> None:
# -> 2833     gcf().tight_layout(pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\figure.py:3640, in Figure.tight_layout(self, pad, h_pad, w_pad, rect)
#    3638 previous_engine = self.get_layout_engine()
#    3639 self.set_layout_engine(engine)
# -> 3640 engine.execute(self)
#    3641 if previous_engine is not None and not isinstance(
#    3642     previous_engine, (TightLayoutEngine, PlaceHolderLayoutEngine)
#    3643 ):
#    3644     _api.warn_external('The figure layout has changed to tight')
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\layout_engine.py:183, in TightLayoutEngine.execute(self, fig)
#     181 renderer = fig._get_renderer()
#     182 with getattr(renderer, "_draw_disabled", nullcontext)():
# --> 183     kwargs = get_tight_layout_figure(
#     184         fig, fig.axes, get_subplotspec_list(fig.axes), renderer,
#     185         pad=info['pad'], h_pad=info['h_pad'], w_pad=info['w_pad'],
#     186         rect=info['rect'])
#     187 if kwargs:
#     188     fig.subplots_adjust(**kwargs)
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\_tight_layout.py:266, in get_tight_layout_figure(fig, axes_list, subplotspec_list, renderer, pad, h_pad, w_pad, rect)
#     261         return {}
#     262     span_pairs.append((
#     263         slice(ss.rowspan.start * div_row, ss.rowspan.stop * div_row),
#     264         slice(ss.colspan.start * div_col, ss.colspan.stop * div_col)))
# --> 266 kwargs = _auto_adjust_subplotpars(fig, renderer,
#     267                                   shape=(max_nrows, max_ncols),
#     268                                   span_pairs=span_pairs,
#     269                                   subplot_list=subplot_list,
#     270                                   ax_bbox_list=ax_bbox_list,
#     271                                   pad=pad, h_pad=h_pad, w_pad=w_pad)
#     273 # kwargs can be none if tight_layout fails...
#     274 if rect is not None and kwargs is not None:
#     275     # if rect is given, the whole subplots area (including
#     276     # labels) will fit into the rect instead of the
#    (...)
#     280     # auto_adjust_subplotpars twice, where the second run
#     281     # with adjusted rect parameters.
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\_tight_layout.py:82, in _auto_adjust_subplotpars(fig, renderer, shape, span_pairs, subplot_list, ax_bbox_list, pad, h_pad, w_pad, rect)
#      80 for ax in subplots:
#      81     if ax.get_visible():
# ---> 82         bb += [martist._get_tightbbox_for_layout_only(ax, renderer)]
#      84 tight_bbox_raw = Bbox.union(bb)
#      85 tight_bbox = fig.transFigure.inverted().transform_bbox(tight_bbox_raw)
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\artist.py:1402, in _get_tightbbox_for_layout_only(obj, *args, **kwargs)
#    1396 """
#    1397 Matplotlib's `.Axes.get_tightbbox` and `.Axis.get_tightbbox` support a
#    1398 *for_layout_only* kwarg; this helper tries to use the kwarg but skips it
#    1399 when encountering third-party subclasses that do not support it.
#    1400 """
#    1401 try:
# -> 1402     return obj.get_tightbbox(*args, **{**kwargs, "for_layout_only": True})
#    1403 except TypeError:
#    1404     return obj.get_tightbbox(*args, **kwargs)
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\axes\_base.py:4551, in _AxesBase.get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4549         if ba:
#    4550             bb.append(ba)
# -> 4551 self._update_title_position(renderer)
#    4552 axbbox = self.get_window_extent(renderer)
#    4553 bb.append(axbbox)
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\axes\_base.py:3118, in _AxesBase._update_title_position(self, renderer)
#    3116 if title.get_text():
#    3117     for ax in axs:
# -> 3118         ax.yaxis.get_tightbbox(renderer)  # update offsetText
#    3119         if ax.yaxis.offsetText.get_text():
#    3120             bb = ax.yaxis.offsetText.get_tightbbox(renderer)
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\axis.py:1353, in Axis.get_tightbbox(self, renderer, for_layout_only)
#    1350     renderer = self.get_figure(root=True)._get_renderer()
#    1351 ticks_to_draw = self._update_ticks()
# -> 1353 self._update_label_position(renderer)
#    1355 # go back to just this axis's tick labels
#    1356 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\axis.py:2675, in YAxis._update_label_position(self, renderer)
#    2671     return
#    2673 # get bounding boxes for this axis and any siblings
#    2674 # that have been set by `fig.align_ylabels()`
# -> 2675 bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    2676 x, y = self.label.get_position()
#    2678 if self.label_position == 'left':
#    2679     # Union with extents of the left spine if present, of the axes otherwise.
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\axis.py:2241, in Axis._get_tick_boxes_siblings(self, renderer)
#    2239 axis = ax._axis_map[name]
#    2240 ticks_to_draw = axis._update_ticks()
# -> 2241 tlb, tlb2 = axis._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    2242 bboxes.extend(tlb)
#    2243 bboxes2.extend(tlb2)
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\axis.py:1332, in Axis._get_ticklabel_bboxes(self, ticks, renderer)
#    1330 if renderer is None:
#    1331     renderer = self.get_figure(root=True)._get_renderer()
# -> 1332 return ([tick.label1.get_window_extent(renderer)
#    1333          for tick in ticks if tick.label1.get_visible()],
#    1334         [tick.label2.get_window_extent(renderer)
#    1335          for tick in ticks if tick.label2.get_visible()])
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\axis.py:1332, in <listcomp>(.0)
#    1330 if renderer is None:
#    1331     renderer = self.get_figure(root=True)._get_renderer()
# -> 1332 return ([tick.label1.get_window_extent(renderer)
#    1333          for tick in ticks if tick.label1.get_visible()],
#    1334         [tick.label2.get_window_extent(renderer)
#    1335          for tick in ticks if tick.label2.get_visible()])
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\text.py:969, in Text.get_window_extent(self, renderer, dpi)
#     964     raise RuntimeError(
#     965         "Cannot get window extent of text w/o renderer. You likely "
#     966         "want to call 'figure.draw_without_rendering()' first.")
#     968 with cbook._setattr_cm(fig, dpi=dpi):
# --> 969     bbox, info, descent = self._get_layout(self._renderer)
#     970     x, y = self.get_unitless_position()
#     971     x, y = self.get_transform().transform((x, y))
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\text.py:373, in Text._get_layout(self, renderer)
#     370 ys = []
#     372 # Full vertical extent of font, including ascenders and descenders:
# --> 373 _, lp_h, lp_d = _get_text_metrics_with_cache(
#     374     renderer, "lp", self._fontproperties,
#     375     ismath="TeX" if self.get_usetex() else False,
#     376     dpi=self.get_figure(root=True).dpi)
#     377 min_dy = (lp_h - lp_d) * self._linespacing
#     379 for i, line in enumerate(lines):
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\text.py:69, in _get_text_metrics_with_cache(renderer, text, fontprop, ismath, dpi)
#      66 """Call ``renderer.get_text_width_height_descent``, caching the results."""
#      67 # Cached based on a copy of fontprop so that later in-place mutations of
#      68 # the passed-in argument do not mess up the cache.
# ---> 69 return _get_text_metrics_with_cache_impl(
#      70     weakref.ref(renderer), text, fontprop.copy(), ismath, dpi)
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\text.py:77, in _get_text_metrics_with_cache_impl(renderer_ref, text, fontprop, ismath, dpi)
#      73 @functools.lru_cache(4096)
#      74 def _get_text_metrics_with_cache_impl(
#      75         renderer_ref, text, fontprop, ismath, dpi):
#      76     # dpi is unused, but participates in cache invalidation (via the renderer).
# ---> 77     return renderer_ref().get_text_width_height_descent(text, fontprop, ismath)
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\backends\backend_agg.py:218, in RendererAgg.get_text_width_height_descent(self, s, prop, ismath)
#     214     ox, oy, width, height, descent, font_image = \
#     215         self.mathtext_parser.parse(s, self.dpi, prop)
#     216     return width, height, descent
# --> 218 font = self._prepare_font(prop)
#     219 font.set_text(s, 0.0, flags=get_hinting_flag())
#     220 w, h = font.get_width_height()  # width and height of unrotated string
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\backends\backend_agg.py:252, in RendererAgg._prepare_font(self, font_prop)
#     248 def _prepare_font(self, font_prop):
#     249     """
#     250     Get the `.FT2Font` for *font_prop*, clear its buffer, and set its size.
#     251     """
# --> 252     font = get_font(_fontManager._find_fonts_by_props(font_prop))
#     253     font.clear()
#     254     size = font_prop.get_size_in_points()
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\font_manager.py:1441, in FontManager._find_fonts_by_props(self, prop, fontext, directory, fallback_to_default, rebuild_if_missing)
#    1438     cprop = prop.copy()
#    1439     cprop.set_family(dfamily)
#    1440     fpaths.append(
# -> 1441         self.findfont(
#    1442             cprop, fontext, directory,
#    1443             fallback_to_default=True,
#    1444             rebuild_if_missing=rebuild_if_missing,
#    1445         )
#    1446     )
#    1447 else:
#    1448     raise ValueError("Failed to find any font, and fallback "
#    1449                      "to the default font was disabled")
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\font_manager.py:1352, in FontManager.findfont(self, prop, fontext, directory, fallback_to_default, rebuild_if_missing)
#    1346 # Pass the relevant rcParams (and the font manager, as `self`) to
#    1347 # _findfont_cached so to prevent using a stale cache entry after an
#    1348 # rcParam was changed.
#    1349 rc_params = tuple(tuple(mpl.rcParams[key]) for key in [
#    1350     "font.serif", "font.sans-serif", "font.cursive", "font.fantasy",
#    1351     "font.monospace"])
# -> 1352 ret = self._findfont_cached(
#    1353     prop, fontext, directory, fallback_to_default, rebuild_if_missing,
#    1354     rc_params)
#    1355 if isinstance(ret, cbook._ExceptionInfo):
#    1356     raise ret.to_exception()
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\font_manager.py:1503, in FontManager._findfont_cached(self, prop, fontext, directory, fallback_to_default, rebuild_if_missing, rc_params)
#    1501     default_prop = prop.copy()
#    1502     default_prop.set_family(self.defaultFamily[fontext])
# -> 1503     return self.findfont(default_prop, fontext, directory,
#    1504                          fallback_to_default=False)
#    1505 else:
#    1506     # This return instead of raise is intentional, as we wish to
#    1507     # cache that it was not found, which will not occur if it was
#    1508     # actually raised.
#    1509     return cbook._ExceptionInfo(
#    1510         ValueError,
#    1511         f"Failed to find font {prop}, and fallback to the default font was "
#    1512         f"disabled"
#    1513     )
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\font_manager.py:1356, in FontManager.findfont(self, prop, fontext, directory, fallback_to_default, rebuild_if_missing)
#    1352 ret = self._findfont_cached(
#    1353     prop, fontext, directory, fallback_to_default, rebuild_if_missing,
#    1354     rc_params)
#    1355 if isinstance(ret, cbook._ExceptionInfo):
# -> 1356     raise ret.to_exception()
#    1357 return ret
#
# ValueError: Failed to find font DejaVu Sans:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0, and fallback to the default font was disabled
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: DejaVu Sans, Bitstream Vera Sans, Computer Modern Sans Serif, Lucida Grande, Verdana, Geneva, Lucid, Arial, Helvetica, Avant Garde, sans-serif
# WARNING:matplotlib.font_manager:findfont: Font family ['DejaVu Sans'] not found. Falling back to DejaVu Sans.
# Error in callback <function _draw_all_if_interactive at 0x000001A0FFB06A70> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\pyplot.py:279, in _draw_all_if_interactive()
#     277 def _draw_all_if_interactive() -> None:
#     278     if matplotlib.is_interactive():
# --> 279         draw_all()
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\_pylab_helpers.py:131, in Gcf.draw_all(cls, force)
#     129 for manager in cls.get_all_fig_managers():
#     130     if force or manager.canvas.figure.stale:
# --> 131         manager.canvas.draw_idle()
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\backend_bases.py:1891, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1889 if not self._is_idle_drawing:
#    1890     with self._idle_draw_cntx():
# -> 1891         self.draw(*args, **kwargs)
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\backends\backend_agg.py:382, in FigureCanvasAgg.draw(self)
#     379 # Acquire a lock on the shared font cache.
#     380 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     381       else nullcontext()):
# --> 382     self.figure.draw(self.renderer)
#     383     # A GUI class may be need to update a window using this draw, so
#     384     # don't forget to call the superclass.
#     385     super().draw()
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\artist.py:94, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      92 @wraps(draw)
#      93 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94     result = draw(artist, renderer, *args, **kwargs)
#      95     if renderer._rasterizing:
#      96         renderer.stop_rasterizing()
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\figure.py:3257, in Figure.draw(self, renderer)
#    3254             # ValueError can occur when resizing a window.
#    3256     self.patch.draw(renderer)
# -> 3257     mimage._draw_list_compositing_images(
#    3258         renderer, self, artists, self.suppressComposite)
#    3260     renderer.close_group('figure')
#    3261 finally:
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\axes\_base.py:3210, in _AxesBase.draw(self, renderer)
#    3207 if artists_rasterized:
#    3208     _draw_rasterized(self.get_figure(root=True), artists_rasterized, renderer)
# -> 3210 mimage._draw_list_compositing_images(
#    3211     renderer, self, artists, self.get_figure(root=True).suppressComposite)
#    3213 renderer.close_group('axes')
#    3214 self.stale = False
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\axis.py:1405, in Axis.draw(self, renderer)
#    1402 renderer.open_group(__name__, gid=self.get_gid())
#    1404 ticks_to_draw = self._update_ticks()
# -> 1405 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    1407 for tick in ticks_to_draw:
#    1408     tick.draw(renderer)
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\axis.py:1332, in Axis._get_ticklabel_bboxes(self, ticks, renderer)
#    1330 if renderer is None:
#    1331     renderer = self.get_figure(root=True)._get_renderer()
# -> 1332 return ([tick.label1.get_window_extent(renderer)
#    1333          for tick in ticks if tick.label1.get_visible()],
#    1334         [tick.label2.get_window_extent(renderer)
#    1335          for tick in ticks if tick.label2.get_visible()])
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\axis.py:1332, in <listcomp>(.0)
#    1330 if renderer is None:
#    1331     renderer = self.get_figure(root=True)._get_renderer()
# -> 1332 return ([tick.label1.get_window_extent(renderer)
#    1333          for tick in ticks if tick.label1.get_visible()],
#    1334         [tick.label2.get_window_extent(renderer)
#    1335          for tick in ticks if tick.label2.get_visible()])
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\text.py:969, in Text.get_window_extent(self, renderer, dpi)
#     964     raise RuntimeError(
#     965         "Cannot get window extent of text w/o renderer. You likely "
#     966         "want to call 'figure.draw_without_rendering()' first.")
#     968 with cbook._setattr_cm(fig, dpi=dpi):
# --> 969     bbox, info, descent = self._get_layout(self._renderer)
#     970     x, y = self.get_unitless_position()
#     971     x, y = self.get_transform().transform((x, y))
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\text.py:373, in Text._get_layout(self, renderer)
#     370 ys = []
#     372 # Full vertical extent of font, including ascenders and descenders:
# --> 373 _, lp_h, lp_d = _get_text_metrics_with_cache(
#     374     renderer, "lp", self._fontproperties,
#     375     ismath="TeX" if self.get_usetex() else False,
#     376     dpi=self.get_figure(root=True).dpi)
#     377 min_dy = (lp_h - lp_d) * self._linespacing
#     379 for i, line in enumerate(lines):
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\text.py:69, in _get_text_metrics_with_cache(renderer, text, fontprop, ismath, dpi)
#      66 """Call ``renderer.get_text_width_height_descent``, caching the results."""
#      67 # Cached based on a copy of fontprop so that later in-place mutations of
#      68 # the passed-in argument do not mess up the cache.
# ---> 69 return _get_text_metrics_with_cache_impl(
#      70     weakref.ref(renderer), text, fontprop.copy(), ismath, dpi)
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\text.py:77, in _get_text_metrics_with_cache_impl(renderer_ref, text, fontprop, ismath, dpi)
#      73 @functools.lru_cache(4096)
#      74 def _get_text_metrics_with_cache_impl(
#      75         renderer_ref, text, fontprop, ismath, dpi):
#      76     # dpi is unused, but participates in cache invalidation (via the renderer).
# ---> 77     return renderer_ref().get_text_width_height_descent(text, fontprop, ismath)
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\backends\backend_agg.py:218, in RendererAgg.get_text_width_height_descent(self, s, prop, ismath)
#     214     ox, oy, width, height, descent, font_image = \
#     215         self.mathtext_parser.parse(s, self.dpi, prop)
#     216     return width, height, descent
# --> 218 font = self._prepare_font(prop)
#     219 font.set_text(s, 0.0, flags=get_hinting_flag())
#     220 w, h = font.get_width_height()  # width and height of unrotated string
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\backends\backend_agg.py:252, in RendererAgg._prepare_font(self, font_prop)
#     248 def _prepare_font(self, font_prop):
#     249     """
#     250     Get the `.FT2Font` for *font_prop*, clear its buffer, and set its size.
#     251     """
# --> 252     font = get_font(_fontManager._find_fonts_by_props(font_prop))
#     253     font.clear()
#     254     size = font_prop.get_size_in_points()
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\font_manager.py:1441, in FontManager._find_fonts_by_props(self, prop, fontext, directory, fallback_to_default, rebuild_if_missing)
#    1438     cprop = prop.copy()
#    1439     cprop.set_family(dfamily)
#    1440     fpaths.append(
# -> 1441         self.findfont(
#    1442             cprop, fontext, directory,
#    1443             fallback_to_default=True,
#    1444             rebuild_if_missing=rebuild_if_missing,
#    1445         )
#    1446     )
#    1447 else:
#    1448     raise ValueError("Failed to find any font, and fallback "
#    1449                      "to the default font was disabled")
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\font_manager.py:1352, in FontManager.findfont(self, prop, fontext, directory, fallback_to_default, rebuild_if_missing)
#    1346 # Pass the relevant rcParams (and the font manager, as `self`) to
#    1347 # _findfont_cached so to prevent using a stale cache entry after an
#    1348 # rcParam was changed.
#    1349 rc_params = tuple(tuple(mpl.rcParams[key]) for key in [
#    1350     "font.serif", "font.sans-serif", "font.cursive", "font.fantasy",
#    1351     "font.monospace"])
# -> 1352 ret = self._findfont_cached(
#    1353     prop, fontext, directory, fallback_to_default, rebuild_if_missing,
#    1354     rc_params)
#    1355 if isinstance(ret, cbook._ExceptionInfo):
#    1356     raise ret.to_exception()
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\font_manager.py:1503, in FontManager._findfont_cached(self, prop, fontext, directory, fallback_to_default, rebuild_if_missing, rc_params)
#    1501     default_prop = prop.copy()
#    1502     default_prop.set_family(self.defaultFamily[fontext])
# -> 1503     return self.findfont(default_prop, fontext, directory,
#    1504                          fallback_to_default=False)
#    1505 else:
#    1506     # This return instead of raise is intentional, as we wish to
#    1507     # cache that it was not found, which will not occur if it was
#    1508     # actually raised.
#    1509     return cbook._ExceptionInfo(
#    1510         ValueError,
#    1511         f"Failed to find font {prop}, and fallback to the default font was "
#    1512         f"disabled"
#    1513     )
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\font_manager.py:1356, in FontManager.findfont(self, prop, fontext, directory, fallback_to_default, rebuild_if_missing)
#    1352 ret = self._findfont_cached(
#    1353     prop, fontext, directory, fallback_to_default, rebuild_if_missing,
#    1354     rc_params)
#    1355 if isinstance(ret, cbook._ExceptionInfo):
# -> 1356     raise ret.to_exception()
#    1357 return ret
#
# ValueError: Failed to find font DejaVu Sans:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0, and fallback to the default font was disabled
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: DejaVu Sans, Bitstream Vera Sans, Computer Modern Sans Serif, Lucida Grande, Verdana, Geneva, Lucid, Arial, Helvetica, Avant Garde, sans-serif
# WARNING:matplotlib.font_manager:findfont: Font family ['DejaVu Sans'] not found. Falling back to DejaVu Sans.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\IPython\core\formatters.py:402, in BaseFormatter.__call__(self, obj)
#     400     pass
#     401 else:
# --> 402     return printer(obj)
#     403 # Finally look for special method names
#     404 method = get_real_method(obj, self.print_method)
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\IPython\core\pylabtools.py:170, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     167     from matplotlib.backend_bases import FigureCanvasBase
#     168     FigureCanvasBase(fig)
# --> 170 fig.canvas.print_figure(bytes_io, **kw)
#     171 data = bytes_io.getvalue()
#     172 if fmt == 'svg':
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\backend_bases.py:2155, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2152     # we do this instead of `self.figure.draw_without_rendering`
#    2153     # so that we can inject the orientation
#    2154     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2155         self.figure.draw(renderer)
#    2156 if bbox_inches:
#    2157     if bbox_inches == "tight":
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\artist.py:94, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      92 @wraps(draw)
#      93 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94     result = draw(artist, renderer, *args, **kwargs)
#      95     if renderer._rasterizing:
#      96         renderer.stop_rasterizing()
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\figure.py:3257, in Figure.draw(self, renderer)
#    3254             # ValueError can occur when resizing a window.
#    3256     self.patch.draw(renderer)
# -> 3257     mimage._draw_list_compositing_images(
#    3258         renderer, self, artists, self.suppressComposite)
#    3260     renderer.close_group('figure')
#    3261 finally:
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\axes\_base.py:3210, in _AxesBase.draw(self, renderer)
#    3207 if artists_rasterized:
#    3208     _draw_rasterized(self.get_figure(root=True), artists_rasterized, renderer)
# -> 3210 mimage._draw_list_compositing_images(
#    3211     renderer, self, artists, self.get_figure(root=True).suppressComposite)
#    3213 renderer.close_group('axes')
#    3214 self.stale = False
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\axis.py:1405, in Axis.draw(self, renderer)
#    1402 renderer.open_group(__name__, gid=self.get_gid())
#    1404 ticks_to_draw = self._update_ticks()
# -> 1405 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    1407 for tick in ticks_to_draw:
#    1408     tick.draw(renderer)
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\axis.py:1332, in Axis._get_ticklabel_bboxes(self, ticks, renderer)
#    1330 if renderer is None:
#    1331     renderer = self.get_figure(root=True)._get_renderer()
# -> 1332 return ([tick.label1.get_window_extent(renderer)
#    1333          for tick in ticks if tick.label1.get_visible()],
#    1334         [tick.label2.get_window_extent(renderer)
#    1335          for tick in ticks if tick.label2.get_visible()])
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\axis.py:1332, in <listcomp>(.0)
# ...
# ---> 77     return renderer_ref().get_text_width_height_descent(text, fontprop, ismath)
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\backends\backend_agg.py:218, in RendererAgg.get_text_width_height_descent(self, s, prop, ismath)
#     214     ox, oy, width, height, descent, font_image = \
#     215         self.mathtext_parser.parse(s, self.dpi, prop)
#     216     return width, height, descent
# --> 218 font = self._prepare_font(prop)
#     219 font.set_text(s, 0.0, flags=get_hinting_flag())
#     220 w, h = font.get_width_height()  # width and height of unrotated string
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\backends\backend_agg.py:252, in RendererAgg._prepare_font(self, font_prop)
#     248 def _prepare_font(self, font_prop):
#     249     """
#     250     Get the `.FT2Font` for *font_prop*, clear its buffer, and set its size.
#     251     """
# --> 252     font = get_font(_fontManager._find_fonts_by_props(font_prop))
#     253     font.clear()
#     254     size = font_prop.get_size_in_points()
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\font_manager.py:1441, in FontManager._find_fonts_by_props(self, prop, fontext, directory, fallback_to_default, rebuild_if_missing)
#    1438     cprop = prop.copy()
#    1439     cprop.set_family(dfamily)
#    1440     fpaths.append(
# -> 1441         self.findfont(
#    1442             cprop, fontext, directory,
#    1443             fallback_to_default=True,
#    1444             rebuild_if_missing=rebuild_if_missing,
#    1445         )
#    1446     )
#    1447 else:
#    1448     raise ValueError("Failed to find any font, and fallback "
#    1449                      "to the default font was disabled")
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\font_manager.py:1352, in FontManager.findfont(self, prop, fontext, directory, fallback_to_default, rebuild_if_missing)
#    1346 # Pass the relevant rcParams (and the font manager, as `self`) to
#    1347 # _findfont_cached so to prevent using a stale cache entry after an
#    1348 # rcParam was changed.
#    1349 rc_params = tuple(tuple(mpl.rcParams[key]) for key in [
#    1350     "font.serif", "font.sans-serif", "font.cursive", "font.fantasy",
#    1351     "font.monospace"])
# -> 1352 ret = self._findfont_cached(
#    1353     prop, fontext, directory, fallback_to_default, rebuild_if_missing,
#    1354     rc_params)
#    1355 if isinstance(ret, cbook._ExceptionInfo):
#    1356     raise ret.to_exception()
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\font_manager.py:1503, in FontManager._findfont_cached(self, prop, fontext, directory, fallback_to_default, rebuild_if_missing, rc_params)
#    1501     default_prop = prop.copy()
#    1502     default_prop.set_family(self.defaultFamily[fontext])
# -> 1503     return self.findfont(default_prop, fontext, directory,
#    1504                          fallback_to_default=False)
#    1505 else:
#    1506     # This return instead of raise is intentional, as we wish to
#    1507     # cache that it was not found, which will not occur if it was
#    1508     # actually raised.
#    1509     return cbook._ExceptionInfo(
#    1510         ValueError,
#    1511         f"Failed to find font {prop}, and fallback to the default font was "
#    1512         f"disabled"
#    1513     )
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\font_manager.py:1356, in FontManager.findfont(self, prop, fontext, directory, fallback_to_default, rebuild_if_missing)
#    1352 ret = self._findfont_cached(
#    1353     prop, fontext, directory, fallback_to_default, rebuild_if_missing,
#    1354     rc_params)
#    1355 if isinstance(ret, cbook._ExceptionInfo):
# -> 1356     raise ret.to_exception()
#    1357 return ret
#
# ValueError: Failed to find font DejaVu Sans:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0, and fallback to the default font was disabled
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family ['DejaVu Sans'] not found. Falling back to DejaVu Sans.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\IPython\core\formatters.py:402, in BaseFormatter.__call__(self, obj)
#     400     pass
#     401 else:
# --> 402     return printer(obj)
#     403 # Finally look for special method names
#     404 method = get_real_method(obj, self.print_method)
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\IPython\core\pylabtools.py:170, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     167     from matplotlib.backend_bases import FigureCanvasBase
#     168     FigureCanvasBase(fig)
# --> 170 fig.canvas.print_figure(bytes_io, **kw)
#     171 data = bytes_io.getvalue()
#     172 if fmt == 'svg':
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\backend_bases.py:2155, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2152     # we do this instead of `self.figure.draw_without_rendering`
#    2153     # so that we can inject the orientation
#    2154     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2155         self.figure.draw(renderer)
#    2156 if bbox_inches:
#    2157     if bbox_inches == "tight":
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\artist.py:94, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      92 @wraps(draw)
#      93 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94     result = draw(artist, renderer, *args, **kwargs)
#      95     if renderer._rasterizing:
#      96         renderer.stop_rasterizing()
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\figure.py:3257, in Figure.draw(self, renderer)
#    3254             # ValueError can occur when resizing a window.
#    3256     self.patch.draw(renderer)
# -> 3257     mimage._draw_list_compositing_images(
#    3258         renderer, self, artists, self.suppressComposite)
#    3260     renderer.close_group('figure')
#    3261 finally:
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\axes\_base.py:3174, in _AxesBase.draw(self, renderer)
#    3171     for spine in self.spines.values():
#    3172         artists.remove(spine)
# -> 3174 self._update_title_position(renderer)
#    3176 if not self.axison:
#    3177     for _axis in self._axis_map.values():
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\axes\_base.py:3118, in _AxesBase._update_title_position(self, renderer)
#    3116 if title.get_text():
#    3117     for ax in axs:
# -> 3118         ax.yaxis.get_tightbbox(renderer)  # update offsetText
#    3119         if ax.yaxis.offsetText.get_text():
#    3120             bb = ax.yaxis.offsetText.get_tightbbox(renderer)
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\axis.py:1353, in Axis.get_tightbbox(self, renderer, for_layout_only)
#    1350     renderer = self.get_figure(root=True)._get_renderer()
#    1351 ticks_to_draw = self._update_ticks()
# -> 1353 self._update_label_position(renderer)
#    1355 # go back to just this axis's tick labels
#    1356 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\axis.py:2675, in YAxis._update_label_position(self, renderer)
#    2671     return
#    2673 # get bounding boxes for this axis and any siblings
#    2674 # that have been set by `fig.align_ylabels()`
# -> 2675 bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    2676 x, y = self.label.get_position()
#    2678 if self.label_position == 'left':
#    2679     # Union with extents of the left spine if present, of the axes otherwise.
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\axis.py:2241, in Axis._get_tick_boxes_siblings(self, renderer)
#    2239 axis = ax._axis_map[name]
#    2240 ticks_to_draw = axis._update_ticks()
# -> 2241 tlb, tlb2 = axis._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    2242 bboxes.extend(tlb)
#    2243 bboxes2.extend(tlb2)
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\axis.py:1332, in Axis._get_ticklabel_bboxes(self, ticks, renderer)
#    1330 if renderer is None:
#    1331     renderer = self.get_figure(root=True)._get_renderer()
# -> 1332 return ([tick.label1.get_window_extent(renderer)
#    1333          for tick in ticks if tick.label1.get_visible()],
#    1334         [tick.label2.get_window_extent(renderer)
#    1335          for tick in ticks if tick.label2.get_visible()])
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\axis.py:1332, in <listcomp>(.0)
#    1330 if renderer is None:
#    1331     renderer = self.get_figure(root=True)._get_renderer()
# -> 1332 return ([tick.label1.get_window_extent(renderer)
#    1333          for tick in ticks if tick.label1.get_visible()],
#    1334         [tick.label2.get_window_extent(renderer)
#    1335          for tick in ticks if tick.label2.get_visible()])
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\text.py:969, in Text.get_window_extent(self, renderer, dpi)
#     964     raise RuntimeError(
#     965         "Cannot get window extent of text w/o renderer. You likely "
#     966         "want to call 'figure.draw_without_rendering()' first.")
#     968 with cbook._setattr_cm(fig, dpi=dpi):
# --> 969     bbox, info, descent = self._get_layout(self._renderer)
#     970     x, y = self.get_unitless_position()
#     971     x, y = self.get_transform().transform((x, y))
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\text.py:373, in Text._get_layout(self, renderer)
#     370 ys = []
#     372 # Full vertical extent of font, including ascenders and descenders:
# --> 373 _, lp_h, lp_d = _get_text_metrics_with_cache(
#     374     renderer, "lp", self._fontproperties,
#     375     ismath="TeX" if self.get_usetex() else False,
#     376     dpi=self.get_figure(root=True).dpi)
#     377 min_dy = (lp_h - lp_d) * self._linespacing
#     379 for i, line in enumerate(lines):
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\text.py:69, in _get_text_metrics_with_cache(renderer, text, fontprop, ismath, dpi)
#      66 """Call ``renderer.get_text_width_height_descent``, caching the results."""
#      67 # Cached based on a copy of fontprop so that later in-place mutations of
#      68 # the passed-in argument do not mess up the cache.
# ---> 69 return _get_text_metrics_with_cache_impl(
#      70     weakref.ref(renderer), text, fontprop.copy(), ismath, dpi)
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\text.py:77, in _get_text_metrics_with_cache_impl(renderer_ref, text, fontprop, ismath, dpi)
#      73 @functools.lru_cache(4096)
#      74 def _get_text_metrics_with_cache_impl(
#      75         renderer_ref, text, fontprop, ismath, dpi):
#      76     # dpi is unused, but participates in cache invalidation (via the renderer).
# ---> 77     return renderer_ref().get_text_width_height_descent(text, fontprop, ismath)
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\backends\backend_agg.py:218, in RendererAgg.get_text_width_height_descent(self, s, prop, ismath)
#     214     ox, oy, width, height, descent, font_image = \
#     215         self.mathtext_parser.parse(s, self.dpi, prop)
#     216     return width, height, descent
# --> 218 font = self._prepare_font(prop)
#     219 font.set_text(s, 0.0, flags=get_hinting_flag())
#     220 w, h = font.get_width_height()  # width and height of unrotated string
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\backends\backend_agg.py:252, in RendererAgg._prepare_font(self, font_prop)
#     248 def _prepare_font(self, font_prop):
#     249     """
#     250     Get the `.FT2Font` for *font_prop*, clear its buffer, and set its size.
#     251     """
# --> 252     font = get_font(_fontManager._find_fonts_by_props(font_prop))
#     253     font.clear()
#     254     size = font_prop.get_size_in_points()
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\font_manager.py:1441, in FontManager._find_fonts_by_props(self, prop, fontext, directory, fallback_to_default, rebuild_if_missing)
#    1438     cprop = prop.copy()
#    1439     cprop.set_family(dfamily)
#    1440     fpaths.append(
# -> 1441         self.findfont(
#    1442             cprop, fontext, directory,
#    1443             fallback_to_default=True,
#    1444             rebuild_if_missing=rebuild_if_missing,
#    1445         )
#    1446     )
#    1447 else:
#    1448     raise ValueError("Failed to find any font, and fallback "
#    1449                      "to the default font was disabled")
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\font_manager.py:1352, in FontManager.findfont(self, prop, fontext, directory, fallback_to_default, rebuild_if_missing)
#    1346 # Pass the relevant rcParams (and the font manager, as `self`) to
#    1347 # _findfont_cached so to prevent using a stale cache entry after an
#    1348 # rcParam was changed.
#    1349 rc_params = tuple(tuple(mpl.rcParams[key]) for key in [
#    1350     "font.serif", "font.sans-serif", "font.cursive", "font.fantasy",
#    1351     "font.monospace"])
# -> 1352 ret = self._findfont_cached(
#    1353     prop, fontext, directory, fallback_to_default, rebuild_if_missing,
#    1354     rc_params)
#    1355 if isinstance(ret, cbook._ExceptionInfo):
#    1356     raise ret.to_exception()
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\font_manager.py:1503, in FontManager._findfont_cached(self, prop, fontext, directory, fallback_to_default, rebuild_if_missing, rc_params)
#    1501     default_prop = prop.copy()
#    1502     default_prop.set_family(self.defaultFamily[fontext])
# -> 1503     return self.findfont(default_prop, fontext, directory,
#    1504                          fallback_to_default=False)
#    1505 else:
#    1506     # This return instead of raise is intentional, as we wish to
#    1507     # cache that it was not found, which will not occur if it was
#    1508     # actually raised.
#    1509     return cbook._ExceptionInfo(
#    1510         ValueError,
#    1511         f"Failed to find font {prop}, and fallback to the default font was "
#    1512         f"disabled"
#    1513     )
#
# File D:\Deep_Learning\Hackathon\.venv\lib\site-packages\matplotlib\font_manager.py:1356, in FontManager.findfont(self, prop, fontext, directory, fallback_to_default, rebuild_if_missing)
#    1352 ret = self._findfont_cached(
#    1353     prop, fontext, directory, fallback_to_default, rebuild_if_missing,
#    1354     rc_params)
#    1355 if isinstance(ret, cbook._ExceptionInfo):
# -> 1356     raise ret.to_exception()
#    1357 return ret
#
# ValueError: Failed to find font DejaVu Sans:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0, and fallback to the default font was disabled
